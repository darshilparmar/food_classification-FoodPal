# %%
import pandas as pd

# %%
dfs = pd.read_csv('data.csv', encoding="utf-8")

# %%
dfs.head()
# Out:
#    NDB_No               Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0    1001        BUTTER,WITH SALT      15.87         717         0.85
# 1    1002  BUTTER,WHIPPED,W/ SALT      16.72         718         0.49
# 2    1003    BUTTER OIL,ANHYDROUS       0.24         876         0.28
# 3    1004             CHEESE,BLUE      42.41         353        21.40
# 4    1005            CHEESE,BRICK      41.11         371        23.24
#
#    Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  \
# 0          81.11     2.11            0.06           0.0           0.06
# 1          78.30     1.62            2.87           0.0           0.06
# 2          99.48     0.00            0.00           0.0           0.00
# 3          28.74     5.11            2.34           0.0           0.50
# 4          29.68     3.18            2.79           0.0           0.51
#
#       ...      Vit_K_(µg)  FA_Sat_(g)  FA_Mono_(g)  FA_Poly_(g)  \
# ...

# %%
export_file = dfs[['Shrt_Desc','Energ_Kcal', 'Carbohydrt_(g)', 'Fiber_TD_(g)', 'Sugar_Tot_(g)', 'Protein_(g)', 'Lipid_Tot_(g)']]

# %%
export_file.to_csv("req_data.csv")

# %%
find_file = dfs[dfs['Shrt_Desc'].str.contains("PIZZA")].head(1)

# %%
find_file.head()
# Out:
#       NDB_No            Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 1294    6152  SAUCE,PIZZA,CND,RTS      86.71          54         2.18
#
#       Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  \
# 1294           1.15      1.3            8.66           2.0           3.78
#
#          ...      Vit_K_(µg)  FA_Sat_(g)  FA_Mono_(g)  FA_Poly_(g)  \
# 1294     ...             NaN        0.46        0.461        0.099
#
#       Cholestrl_(mg)  GmWt_1  GmWt_Desc1  GmWt_2  GmWt_Desc2  Refuse_Pct
# 1294             0.0    63.0     .25 cup     NaN         NaN         0.0
#
# [1 rows x 53 columns]

# %%
req_data = find_file[['Shrt_Desc','Energ_Kcal', 'Carbohydrt_(g)', 'Fiber_TD_(g)', 'Sugar_Tot_(g)', 'Protein_(g)', 'Lipid_Tot_(g)']]

# %%
req_data.reset_index(drop=True)
# Out:
#              Shrt_Desc  Energ_Kcal  Carbohydrt_(g)  Fiber_TD_(g)  \
# 0  SAUCE,PIZZA,CND,RTS          54            8.66           2.0
#
#    Sugar_Tot_(g)  Protein_(g)  Lipid_Tot_(g)
# 0           3.78         2.18           1.15

# %%
req_data = req_data.replace('\n','', regex=True)

# %%
shrt_desc = req_data.iloc[0]['Shrt_Desc']  

Energ_Kcal = req_data.iloc[0]['Energ_Kcal']
Carbohydrt =req_data.iloc[0]['Carbohydrt_(g)']

Fiber_TD = req_data.iloc[0]['Fiber_TD_(g)']

Sugar_Tot = req_data.iloc[0]['Sugar_Tot_(g)']

Protein = req_data.iloc[0]['Protein_(g)']

Lipid_Tot= req_data.iloc[0]['Lipid_Tot_(g)']

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1 entries, 1294 to 1294
# Data columns (total 7 columns):
# Shrt_Desc         1 non-null object
# Energ_Kcal        1 non-null int64
# Carbohydrt_(g)    1 non-null float64
# Fiber_TD_(g)      1 non-null float64
# Sugar_Tot_(g)     1 non-null float64
# Protein_(g)       1 non-null float64
# Lipid_Tot_(g)     1 non-null float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 144.0+ bytes

# %%
import pymysql
import re
#database connection
connection = pymysql.connect(host="localhost",user="root",passwd="",database="foodcal" )
cursor = connection.cursor()
# some other statements  with the help of cursor
# sql = "INSERT INTO `image_details`(`img_id`, `Shrt_Desc`, `Energ_Kcal`, `Carbohydrt_(g)`, `Fiber_TD_(g)`, `Sugar_Tot_(g)`, `Protein_(g)`, `Lipid_Tot_(g)`) VALUES ({},{},{1},{1},{1},{1},{1},{1})".format(4, shrt_desc, Energ_Kcal,Carbohydrt, Fiber_TD,Sugar_Tot, Protein ,Lipid_Tot )
sql = """
LOAD DATA INFILE 'C:\\xampp\\htdocs\\foodpal\\python\\data\\req_data.csv' 
INTO TABLE image_details 
FIELDS TERMINATED BY ',' 
ENCLOSED BY '"'
LINES TERMINATED BY '\n'
IGNORE 1 ROWS;"""
cursor.execute(sql)
connection.commit()
connection.close()
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-128-1b76745fe030> in <module>()
#      14 LINES TERMINATED BY '\n'
#      15 IGNORE 1 ROWS;"""
# ---> 16 cursor.execute(sql)
#      17 connection.commit()
#      18 connection.close()
#
# ~\Anaconda3\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     168         query = self.mogrify(query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#     172         return result
#
# ~\Anaconda3\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     326         self._last_executed = q
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#     330         return self.rowcount
#
# ~\Anaconda3\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
# ...
